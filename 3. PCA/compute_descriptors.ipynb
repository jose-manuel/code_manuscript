# %% [markdown]
# # Compute Descriptors
#
# Computation of descriptors used in Principal Componant Analysis:
#
# 1. Molecular Descriptors
#     - num_heavy_atoms
#     - molecular_weight
#     - num_rings
#     - num_rings_arom
#     - num_rings_ali
#     - num_hbd
#     - num_hba
#     - slogp
#     - tpsa
#     - num_rotatable_bond
#     - num_atom_oxygen
#     - num_atom_nitrogen
#     - ring_size_min
#     - ring_size_max
#     - frac_sp3
#
#
# 2. Subset Annotations
#     - num_lipinski_violations
#     - num_veber_violations

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# standard
from pathlib import Path
import sys
import warnings
# data
import pandas as pd
import numpy as np
import rdkit
# plot
import matplotlib.pyplot as plt
import seaborn as sns
# notebook
from IPython.core.interactiveshell import InteractiveShell
# dev
PROJECT_DIR = list(Path("..").absolute().parents)[1]
sys.path.append(str(PROJECT_DIR))
import utils as u
Path("../tmp").mkdir(exist_ok=True)

# configure notebook session
warnings.filterwarnings('ignore')
InteractiveShell.ast_node_interactivity = "all"


# log core package versions
print("RDKit".ljust(30), rdkit.__version__)
print("Pandas".ljust(30), pd.__version__)
# Out:
# RDKit                          2020.03.6
# Pandas                         1.1.4
# /home/gally/Software/anaconda3/envs/paper_michael/lib/python3.8/site-packages/tqdm/std.py:703: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# ### Globals

# %%
# input
input_inhouse = '../tmp/internal_cpds_std.tsv'
input_drugbank = '../tmp/drugbank_std.tsv'
input_chemblnp = '../tmp/chembl_np_std.tsv'

# output
output_inhouse = '../tmp/internal_cpds_desc.tsv.gz'
output_drugbank = '../tmp/drugbank_desc.tsv.gz'
output_chemblnp =  '../tmp/chembl_np_desc.tsv.gz'

# %% [markdown]
# ## Load data

# %%
df_inhouse = u.read_tsv(input_inhouse)
print(f"Loaded {len(df_inhouse):,} records for inhouse")

df_drugbank = u.read_tsv(input_drugbank)
print(f"Loaded {len(df_drugbank):,} records for drugbank")

df_chemblnp = u.read_tsv(input_chemblnp)
print(f"Loaded {len(df_chemblnp):,} records for chemblnp")
# Out:
# Loaded 168 records for inhouse
# Loaded 7,472 records for drugbank
# Loaded 30,655 records for chemblnp

# %% [markdown]
# ## Compute descriptors

# %%
df_inhouse = u.compute_descriptors_df(df_inhouse, smiles_col='Smiles')
df_inhouse
# Out:
#      Compound_Id CpdClass                                             Smiles  \
# 0         408580   QN-C-S  COc1ccc2nccc(C(O)C3CC4CCN3CC43CC(=O)c4ccccc4O3...
# 1         408614   QN-C-S  COc1ccc2nccc(C(O)C3CC4CCN3CC43CC(=O)c4cc(Br)cc...
# 2         409679   QN-C-S  COc1ccc2nccc(C(O)C3CC4CCN3CC43CC(=O)c4cc(Cl)cc...
# 3         408605   QN-C-S  COc1ccc2nccc(C(O)C3CC4CCN3CC43CC(=O)c4cc(F)ccc...
# 4         408610   QN-C-S  COc1ccc2c(c1)OC1(CC2=O)CN2CCC1CC2C(O)c1ccnc2cc...
# ..           ...      ...                                                ...
# 163       412370   G-THPI  COc1cc(OC)c2c(c1Cl)OC1(CCC3(CC1C)OCCc1c3[nH]c3...
# 164       412371   G-THPI  COc1cc(OC)c2c(c1Cl)OC1(CCC3(CC1C)OCCc1c3[nH]c3...
# 165       412372   G-THPI  COc1cc(OC)c2c(c1Cl)OC1(CCC3(CC1C)OCCc1c3[nH]c3...
# 166       412373   G-THPI  COc1cc(OC)c2c(c1Cl)OC1(CCC3(CC1C)OCCc1c3[nH]c3...
# 167       412374   G-THPI  CCc1cccc2c3c([nH]c12)C1(CCC2(Oc4c(Cl)c(OC)cc(O...
#
#      num_heavy_atoms  molecular_weight  num_rings  num_rings_arom  \
# 0               32.0          430.1893        7.0             3.0
# 1               33.0          508.0998        7.0             3.0
# 2               33.0          464.1503        7.0             3.0
# 3               33.0          448.1798        7.0             3.0
# 4               34.0          460.1998        7.0             3.0
# ..               ...               ...        ...             ...
# 163             34.0          501.1110        6.0             3.0
# 164             34.0          485.1405        6.0             3.0
# 165             36.0          509.1969        6.0             3.0
# 166             34.0          501.1110        6.0             3.0
# 167             35.0          495.1813        6.0             3.0
#
#      num_rings_ali  num_hbd  num_hba   slogp   tpsa  num_rotatable_bond  \
# 0              4.0      1.0      6.0  3.7752  71.89                 3.0
# 1              4.0      1.0      6.0  4.5377  71.89                 3.0
# 2              4.0      1.0      6.0  4.4286  71.89                 3.0
# 3              4.0      1.0      6.0  3.9143  71.89                 3.0
# 4              4.0      1.0      7.0  3.7838  81.12                 4.0
# ..             ...      ...      ...     ...    ...                 ...
# 163            3.0      1.0      6.0  6.0940  69.78                 2.0
# 164            3.0      1.0      6.0  5.5797  69.78                 2.0
# 165            3.0      1.0      6.0  6.5640  69.78                 3.0
# 166            3.0      1.0      6.0  6.0940  69.78                 2.0
# 167            3.0      1.0      6.0  6.0030  69.78                 3.0
#
#      num_atom_oxygen  num_atom_nitrogen  ring_size_min  ring_size_max  \
# 0                4.0                2.0            6.0            6.0
# 1                4.0                2.0            6.0            6.0
# 2                4.0                2.0            6.0            6.0
# 3                4.0                2.0            6.0            6.0
# 4                5.0                2.0            6.0            6.0
# ..               ...                ...            ...            ...
# 163              5.0                1.0            5.0            6.0
# 164              5.0                1.0            5.0            6.0
# 165              5.0                1.0            5.0            6.0
# 166              5.0                1.0            5.0            6.0
# 167              5.0                1.0            5.0            6.0
#
#      frac_sp3  num_lipinski_violations  num_veber_violations
# 0    0.384615                      0.0                   0.0
# 1    0.384615                      1.0                   0.0
# 2    0.384615                      0.0                   0.0
# 3    0.384615                      0.0                   0.0
# 4    0.407407                      0.0                   0.0
# ..        ...                      ...                   ...
# 163  0.423077                      2.0                   0.0
# 164  0.423077                      1.0                   0.0
# 165  0.482759                      2.0                   0.0
# 166  0.423077                      2.0                   0.0
# 167  0.464286                      1.0                   0.0
#
# [168 rows x 20 columns]

# %%
df_drugbank = u.compute_descriptors_df(df_drugbank, smiles_col='Smiles')
df_drugbank
# Out:
#      DATABASE_ID                                             Smiles  \
# 0        DB00035  N=C(N)NCCCC(NC(=O)C1CCCN1C(=O)C1CSSCCC(=O)NC(C...
# 1        DB00104  CC(O)C(CO)NC(=O)C1CSSCC(NC(=O)C(N)Cc2ccccc2)C(...
# 2        DB00114                   Cc1ncc(CO[PH](=O)(=O)O)c(C=O)c1O
# 3        DB00118  C[S+](CCC(N)C(=O)[O-])CC1OC(n2cnc3c(=N)[nH]cnc...
# 4        DB00119                                       CC(=O)C(=O)O
# ...          ...                                                ...
# 7467     DB15586                                 O=C1OCCc2oc(O)cc21
# 7468     DB15588  CC1CCC2(C(=O)O)CCC3(C)C(=CCC4C5(C)CCC(O)C(C)(C...
# 7469     DB15589                              COc1cc(CCC(C)=O)ccc1O
# 7470     DB15590    COc1cc(C2c3cc4c(cc3Cc3coc(O)c32)OCO4)cc(OC)c1OC
# 7471     DB15596                CN(C)CC(CN1c2ccccc2Sc2ccccc21)N(C)C
#
#       num_heavy_atoms  molecular_weight  num_rings  num_rings_arom  \
# 0                74.0         1068.4270        4.0             2.0
# 1                71.0         1018.4405        5.0             4.0
# 2                16.0          247.0246        1.0             1.0
# 3                27.0          398.1372        3.0             2.0
# 4                 6.0           88.0160        0.0             0.0
# ...               ...               ...        ...             ...
# 7467             11.0          154.0266        2.0             1.0
# 7468             33.0          456.3603        5.0             0.0
# 7469             14.0          194.0943        1.0             1.0
# 7470             29.0          396.1209        5.0             3.0
# 7471             23.0          327.1769        3.0             2.0
#
#       num_rings_ali  num_hbd  num_hba   slogp    tpsa  num_rotatable_bond  \
# 0               2.0     18.0     26.0 -4.1320  435.41                19.0
# 1               1.0     15.0     20.0 -0.8054  332.22                17.0
# 2               0.0      2.0      7.0  0.6879  113.79                 4.0
# 3               1.0      6.0     11.0 -3.4265  186.19                 7.0
# 4               0.0      1.0      3.0 -0.3400   54.37                 1.0
# ...             ...      ...      ...     ...     ...                 ...
# 7467            1.0      1.0      4.0  0.6981   59.67                 0.0
# 7468            5.0      2.0      3.0  7.0895   57.53                 1.0
# 7469            0.0      1.0      3.0  1.9224   46.53                 4.0
# 7470            2.0      1.0      7.0  3.8241   79.52                 4.0
# 7471            1.0      0.0      3.0  3.7811    9.72                 5.0
#
#       num_atom_oxygen  num_atom_nitrogen  ring_size_min  ring_size_max  \
# 0                12.0               14.0            5.0           20.0
# 1                10.0               10.0            5.0           20.0
# 2                 6.0                1.0            6.0            6.0
# 3                 5.0                6.0            5.0            6.0
# 4                 3.0                0.0            0.0            0.0
# ...               ...                ...            ...            ...
# 7467              4.0                0.0            5.0            6.0
# 7468              3.0                0.0            6.0            6.0
# 7469              3.0                0.0            6.0            6.0
# 7470              7.0                0.0            5.0            6.0
# 7471              0.0                3.0            6.0            6.0
#
#       frac_sp3  num_lipinski_violations  num_veber_violations
# 0     0.478261                      3.0                   2.0
# 1     0.448980                      3.0                   2.0
# 2     0.250000                      0.0                   0.0
# 3     0.600000                      2.0                   1.0
# 4     0.333333                      1.0                   0.0
# ...        ...                      ...                   ...
# 7467  0.285714                      0.0                   0.0
# 7468  0.900000                      1.0                   0.0
# 7469  0.363636                      0.0                   0.0
# 7470  0.272727                      0.0                   0.0
# 7471  0.368421                      0.0                   0.0
#
# [7472 rows x 19 columns]

# %%
df_chemblnp = u.compute_descriptors_df(df_chemblnp, smiles_col='Smiles')
df_chemblnp
# Out:
#                 Name      chembl_id  \
# 0       CHEMBL503865   CHEMBL503865
# 1       CHEMBL503873   CHEMBL503873
# 2       CHEMBL504077   CHEMBL504077
# 3       CHEMBL501665   CHEMBL501665
# 4       CHEMBL501672   CHEMBL501672
# ...              ...            ...
# 30650  CHEMBL4295025  CHEMBL4295025
# 30651  CHEMBL4294139  CHEMBL4294139
# 30652  CHEMBL4294508  CHEMBL4294508
# 30653  CHEMBL4294241  CHEMBL4294241
# 30654  CHEMBL4296740  CHEMBL4296740
#
#                                                   Smiles  num_heavy_atoms  \
# 0      CC(=O)OC1/C(C)=C\C2OC(=O)C3(C)OC23C(OC(C)=O)C2...             41.0
# 1      CC(=O)C1(O)CCC2(O)C3(O)CC=C4CC(O)CCC4(C)C3CC(O...             37.0
# 2      COc1ccc2c(c1OC)C(CC1(C)C=Cc3c(c4cccc(OC)c4n(C)...             46.0
# 3      CC(C)=CC1CC(C)(O)C2C3CCC4C5(C)CCC(O)C(C)(C)C5C...             34.0
# 4      CCCCCC1CCCCCCCCCC(=O)OC2C(O)C(C)OC(OC3C(OC(CO)...             55.0
# ...                                                  ...              ...
# 30650  CC=C(C)C(=O)OCC1(C)C2CC(C)C34C=C(C)C(OC(=O)C(C...             37.0
# 30651  CC1(O)CC2(O)C=CC3=C(C(=O)c4cccc(O)c4C3=O)C2(O)...             27.0
# 30652  O=C1NC(=O)C(c2ccc(O)c([N+](=O)[O-])c2)=C1c1ccccc1             23.0
# 30653                         COC(=O)C(O)Cc1ccc(O)c(O)c1             15.0
# 30654                            COc1ccc(O)c(C(C)(C)C)c1             13.0
#
#        molecular_weight  num_rings  num_rings_arom  num_rings_ali  num_hbd  \
# 0              580.2156        4.0             0.0            4.0      2.0
# 1              510.2618        5.0             1.0            4.0      4.0
# 2              618.2366        8.0             5.0            3.0      0.0
# 3              472.3553        6.0             0.0            6.0      2.0
# 4              792.4507        4.0             0.0            4.0      6.0
# ...                 ...        ...             ...            ...      ...
# 30650          512.2774        4.0             0.0            4.0      2.0
# 30651          372.0845        4.0             1.0            3.0      5.0
# 30652          310.0590        3.0             2.0            1.0      2.0
# 30653          212.0685        1.0             1.0            0.0      3.0
# 30654          180.1150        1.0             1.0            0.0      1.0
#
#        num_hba   slogp    tpsa  num_rotatable_bond  num_atom_oxygen  \
# 0         13.0  0.4304  184.49                 4.0             13.0
# 1          7.0  3.0951  124.29                 4.0              7.0
# 2          9.0  6.8587   80.62                 5.0              7.0
# 3          4.0  5.8550   58.92                 1.0              4.0
# 4         16.0  2.1278  229.36                 8.0             16.0
# ...        ...     ...     ...                 ...              ...
# 30650      7.0  3.8494  110.13                 5.0              7.0
# 30651      8.0 -0.8155  152.36                 0.0              8.0
# 30652      7.0  1.8676  109.54                 3.0              5.0
# 30653      5.0  0.1742   86.99                 3.0              5.0
# 30654      2.0  2.6983   29.46                 1.0              2.0
#
#        num_atom_nitrogen  ring_size_min  ring_size_max  frac_sp3  \
# 0                    0.0            3.0           10.0  0.678571
# 1                    0.0            5.0            6.0  0.600000
# 2                    2.0            5.0            6.0  0.270270
# 3                    0.0            5.0            6.0  0.933333
# 4                    0.0            6.0           22.0  0.948718
# ...                  ...            ...            ...       ...
# 30650                0.0            3.0            7.0  0.633333
# 30651                0.0            6.0            6.0  0.315789
# 30652                2.0            5.0            6.0  0.000000
# 30653                0.0            6.0            6.0  0.300000
# 30654                0.0            6.0            6.0  0.454545
#
#        num_lipinski_violations  num_veber_violations
# 0                          2.0                   1.0
# 1                          1.0                   0.0
# 2                          2.0                   0.0
# 3                          1.0                   0.0
# 4                          3.0                   1.0
# ...                        ...                   ...
# 30650                      1.0                   0.0
# 30651                      0.0                   1.0
# 30652                      0.0                   0.0
# 30653                      0.0                   0.0
# 30654                      0.0                   0.0
#
# [30655 rows x 20 columns]

# %% [markdown]
# ## Check results

# %%
# check if there are some failed molecules
df_inhouse[df_inhouse['num_heavy_atoms'].isna()]
# Out:
# Empty DataFrame
# Columns: [Compound_Id, CpdClass, Smiles, num_heavy_atoms, molecular_weight, num_rings, num_rings_arom, num_rings_ali, num_hbd, num_hba, slogp, tpsa, num_rotatable_bond, num_atom_oxygen, num_atom_nitrogen, ring_size_min, ring_size_max, frac_sp3, num_lipinski_violations, num_veber_violations]
# Index: []

# %%
# check if there are some failed molecules
df_drugbank[df_drugbank['num_heavy_atoms'].isna()]
# Out:
# Empty DataFrame
# Columns: [DATABASE_ID, Smiles, num_heavy_atoms, molecular_weight, num_rings, num_rings_arom, num_rings_ali, num_hbd, num_hba, slogp, tpsa, num_rotatable_bond, num_atom_oxygen, num_atom_nitrogen, ring_size_min, ring_size_max, frac_sp3, num_lipinski_violations, num_veber_violations]
# Index: []

# %%
# check if there are some failed molecules
df_chemblnp[df_chemblnp['num_heavy_atoms'].isna()]
# Out:
# Empty DataFrame
# Columns: [Name, chembl_id, Smiles, num_heavy_atoms, molecular_weight, num_rings, num_rings_arom, num_rings_ali, num_hbd, num_hba, slogp, tpsa, num_rotatable_bond, num_atom_oxygen, num_atom_nitrogen, ring_size_min, ring_size_max, frac_sp3, num_lipinski_violations, num_veber_violations]
# Index: []

# %% [markdown]
# There was no error during the molecular descriptor computation.

# %% [markdown]
# ## Export results

# %%
u.write_tsv(df_inhouse, output_inhouse)
u.write_tsv(df_drugbank, output_drugbank)
u.write_tsv(df_chemblnp, output_chemblnp)
